# %%
import pandas as pd
from datetime import datetime, timedelta, date
import group2setting
import boto3
from sqlalchemy import create_engine
from io import StringIO


def load_311_daily_data_from_s3(selected_date_str):
    
    
    bucket = group2setting.s3_bucket
    file_name = "Group_2_311_daily{}.csv".format(selected_date_str)
    print(file_name)
    
    s3 = boto3.client('s3') 
    obj = s3.get_object(Bucket= bucket, Key= file_name) 
    
    data_sample = pd.read_csv(obj['Body'])
    
    print(data_sample.shape)
    
    #print(data_sample.columns)
    sub_df = data_sample.loc[:, ['unique_key', 'created_date','closed_date',
                                'agency','agency_name','complaint_type',
                                'descriptor','incident_zip','city',
                                'status','resolution_description',
                                'resolution_action_updated_date','borough','open_data_channel_type',
                                'latitude','longitude']]
    return sub_df


def save_into_rds_by_name(sub_df, table_name = 't_311_items'):
    
    print(sub_df.shape)
    
    # create engine by sqlalchemy + pymysql
    engine = create_engine(group2setting.rds_mysql_engine)
    
    # to transfer csv to mysql by pandas.to_sql
    sub_df.to_sql(con=engine, name=table_name, if_exists='append', index=False)
    
    print(table_name + " save into rds successfully")

    
# Defining lambda_handler function
def lambda_handler(event, context):
    selected_date = datetime.today() - timedelta(days = 2)
    selected_date_str = selected_date.strftime('%Y%m%d')
    
    sub_df = load_311_daily_data_from_s3(selected_date_str)
    
    save_into_rds_by_name(sub_df)

# %%
lambda_handler(1, 2)
# Out:
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210504.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210504.csv from s3 successfully
# (64, 35)
# (64, 16)
# t_311_items save into rds successfully

# %%
import time
def load_history():
    selected_date = datetime.today() - timedelta(days = 1)
    start_date = datetime.fromisoformat('2021-02-15')
    
    while start_date < selected_date:
        print(start_date)
        selected_date_str = start_date.strftime('%Y%m%d')
        
        sub_df = load_311_daily_data_from_s3(selected_date_str)
    
        save_into_rds_by_name(sub_df)
        time.sleep(1)
        
        start_date = start_date + timedelta(days = 1)

load_history()
# Out:
# 2021-02-15 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210215.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210215.csv from s3 successfully
# (808, 41)
# (808, 16)
# t_311_items save into rds successfully
# 2021-02-16 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210216.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210216.csv from s3 successfully
# (814, 41)
# (814, 16)
# t_311_items save into rds successfully
# 2021-02-17 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210217.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210217.csv from s3 successfully
# (774, 41)
# (774, 16)
# t_311_items save into rds successfully
# 2021-02-18 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210218.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210218.csv from s3 successfully
# (719, 41)
# (719, 16)
# t_311_items save into rds successfully
# 2021-02-19 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210219.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210219.csv from s3 successfully
# (836, 41)
# (836, 16)
# t_311_items save into rds successfully
# 2021-02-20 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210220.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210220.csv from s3 successfully
# (1266, 41)
# (1266, 16)
# t_311_items save into rds successfully
# 2021-02-21 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210221.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210221.csv from s3 successfully
# (1226, 41)
# (1226, 16)
# t_311_items save into rds successfully
# 2021-02-22 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210222.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210222.csv from s3 successfully
# (695, 41)
# (695, 16)
# t_311_items save into rds successfully
# 2021-02-23 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210223.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210223.csv from s3 successfully
# (776, 41)
# (776, 16)
# t_311_items save into rds successfully
# 2021-02-24 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210224.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210224.csv from s3 successfully
# (1002, 40)
# (1002, 16)
# t_311_items save into rds successfully
# 2021-02-25 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210225.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210225.csv from s3 successfully
# (1018, 42)
# (1018, 16)
# t_311_items save into rds successfully
# 2021-02-26 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210226.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210226.csv from s3 successfully
# (1266, 41)
# (1266, 16)
# t_311_items save into rds successfully
# 2021-02-27 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210227.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210227.csv from s3 successfully
# (1762, 41)
# (1762, 16)
# t_311_items save into rds successfully
# 2021-02-28 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210228.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210228.csv from s3 successfully
# (1602, 41)
# (1602, 16)
# t_311_items save into rds successfully
# 2021-03-01 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210301.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210301.csv from s3 successfully
# (778, 41)
# (778, 16)
# t_311_items save into rds successfully
# 2021-03-02 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210302.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210302.csv from s3 successfully
# (720, 40)
# (720, 16)
# t_311_items save into rds successfully
# 2021-03-03 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210303.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210303.csv from s3 successfully
# (1024, 40)
# (1024, 16)
# t_311_items save into rds successfully
# 2021-03-04 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210304.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210304.csv from s3 successfully
# (806, 41)
# (806, 16)
# t_311_items save into rds successfully
# 2021-03-05 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210305.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210305.csv from s3 successfully
# (917, 41)
# (917, 16)
# t_311_items save into rds successfully
# 2021-03-06 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210306.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210306.csv from s3 successfully
# (1297, 41)
# (1297, 16)
# t_311_items save into rds successfully
# 2021-03-07 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210307.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210307.csv from s3 successfully
# (1231, 40)
# (1231, 16)
# t_311_items save into rds successfully
# 2021-03-08 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210308.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210308.csv from s3 successfully
# (854, 40)
# (854, 16)
# t_311_items save into rds successfully
# 2021-03-09 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210309.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210309.csv from s3 successfully
# (1398, 41)
# (1398, 16)
# t_311_items save into rds successfully
# 2021-03-10 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210310.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210310.csv from s3 successfully
# (1021, 41)
# (1021, 16)
# t_311_items save into rds successfully
# 2021-03-11 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210311.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210311.csv from s3 successfully
# (1862, 41)
# (1862, 16)
# t_311_items save into rds successfully
# 2021-03-12 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210312.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210312.csv from s3 successfully
# (1912, 41)
# (1912, 16)
# t_311_items save into rds successfully
# 2021-03-13 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210313.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210313.csv from s3 successfully
# (1531, 41)
# (1531, 16)
# t_311_items save into rds successfully
# 2021-03-14 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210314.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210314.csv from s3 successfully
# (1361, 41)
# (1361, 16)
# t_311_items save into rds successfully
# 2021-03-15 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210315.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210315.csv from s3 successfully
# (840, 42)
# (840, 16)
# t_311_items save into rds successfully
# 2021-03-16 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210316.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210316.csv from s3 successfully
# (818, 41)
# (818, 16)
# t_311_items save into rds successfully
# 2021-03-17 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210317.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210317.csv from s3 successfully
# (968, 41)
# (968, 16)
# t_311_items save into rds successfully
# 2021-03-18 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210318.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210318.csv from s3 successfully
# (807, 41)
# (807, 16)
# t_311_items save into rds successfully
# 2021-03-19 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210319.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210319.csv from s3 successfully
# (999, 41)
# (999, 16)
# t_311_items save into rds successfully
# 2021-03-20 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210320.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210320.csv from s3 successfully
# (2123, 41)
# (2123, 16)
# t_311_items save into rds successfully
# 2021-03-21 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210321.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210321.csv from s3 successfully
# (2560, 40)
# (2560, 16)
# t_311_items save into rds successfully
# 2021-03-22 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210322.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210322.csv from s3 successfully
# (1273, 41)
# (1273, 16)
# t_311_items save into rds successfully
# 2021-03-23 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210323.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210323.csv from s3 successfully
# (1379, 41)
# (1379, 16)
# t_311_items save into rds successfully
# 2021-03-24 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210324.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210324.csv from s3 successfully
# (847, 41)
# (847, 16)
# t_311_items save into rds successfully
# 2021-03-25 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210325.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210325.csv from s3 successfully
# (1499, 42)
# (1499, 16)
# t_311_items save into rds successfully
# 2021-03-26 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210326.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210326.csv from s3 successfully
# (1837, 41)
# (1837, 16)
# t_311_items save into rds successfully
# 2021-03-27 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210327.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210327.csv from s3 successfully
# (2725, 41)
# (2725, 16)
# t_311_items save into rds successfully
# 2021-03-28 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210328.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210328.csv from s3 successfully
# (2041, 41)
# (2041, 16)
# t_311_items save into rds successfully
# 2021-03-29 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210329.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210329.csv from s3 successfully
# (970, 41)
# (970, 16)
# t_311_items save into rds successfully
# 2021-03-30 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210330.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210330.csv from s3 successfully
# (1033, 41)
# (1033, 16)
# t_311_items save into rds successfully
# 2021-03-31 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210331.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210331.csv from s3 successfully
# (794, 41)
# (794, 16)
# t_311_items save into rds successfully
# 2021-04-01 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210401.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210401.csv from s3 successfully
# (792, 41)
# (792, 16)
# t_311_items save into rds successfully
# 2021-04-02 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210402.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210402.csv from s3 successfully
# (854, 39)
# (854, 16)
# t_311_items save into rds successfully
# 2021-04-03 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210403.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210403.csv from s3 successfully
# (1856, 40)
# (1856, 16)
# t_311_items save into rds successfully
# 2021-04-04 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210404.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210404.csv from s3 successfully
# (2520, 40)
# (2520, 16)
# t_311_items save into rds successfully
# 2021-04-05 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210405.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210405.csv from s3 successfully
# (1240, 41)
# (1240, 16)
# t_311_items save into rds successfully
# 2021-04-06 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210406.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210406.csv from s3 successfully
# (1717, 41)
# (1717, 16)
# t_311_items save into rds successfully
# 2021-04-07 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210407.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210407.csv from s3 successfully
# (1573, 41)
# (1573, 16)
# t_311_items save into rds successfully
# 2021-04-08 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210408.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210408.csv from s3 successfully
# (1489, 41)
# (1489, 16)
# t_311_items save into rds successfully
# 2021-04-09 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210409.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210409.csv from s3 successfully
# (1565, 42)
# (1565, 16)
# t_311_items save into rds successfully
# 2021-04-10 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210410.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210410.csv from s3 successfully
# (2987, 40)
# (2987, 16)
# t_311_items save into rds successfully
# 2021-04-11 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210411.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210411.csv from s3 successfully
# (2159, 41)
# (2159, 16)
# t_311_items save into rds successfully
# 2021-04-12 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210412.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210412.csv from s3 successfully
# (789, 41)
# (789, 16)
# t_311_items save into rds successfully
# 2021-04-13 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210413.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210413.csv from s3 successfully
# (1450, 41)
# (1450, 16)
# t_311_items save into rds successfully
# 2021-04-14 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210414.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210414.csv from s3 successfully
# (1571, 42)
# (1571, 16)
# t_311_items save into rds successfully
# 2021-04-15 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210415.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210415.csv from s3 successfully
# (923, 41)
# (923, 16)
# t_311_items save into rds successfully
# 2021-04-16 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210416.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210416.csv from s3 successfully
# (1085, 42)
# (1085, 16)
# t_311_items save into rds successfully
# 2021-04-17 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210417.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210417.csv from s3 successfully
# (2451, 40)
# (2451, 16)
# t_311_items save into rds successfully
# 2021-04-18 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210418.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210418.csv from s3 successfully
# (2955, 41)
# (2955, 16)
# t_311_items save into rds successfully
# 2021-04-19 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210419.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210419.csv from s3 successfully
# (1361, 41)
# (1361, 16)
# t_311_items save into rds successfully
# 2021-04-20 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210420.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210420.csv from s3 successfully
# (1859, 41)
# (1859, 16)
# t_311_items save into rds successfully
# 2021-04-21 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210421.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210421.csv from s3 successfully
# (934, 41)
# (934, 16)
# t_311_items save into rds successfully
# 2021-04-22 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210422.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210422.csv from s3 successfully
# (784, 42)
# (784, 16)
# t_311_items save into rds successfully
# 2021-04-23 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210423.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210423.csv from s3 successfully
# (1633, 41)
# (1633, 16)
# t_311_items save into rds successfully
# 2021-04-24 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210424.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210424.csv from s3 successfully
# (3461, 41)
# (3461, 16)
# t_311_items save into rds successfully
# 2021-04-25 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210425.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210425.csv from s3 successfully
# (2549, 41)
# (2549, 16)
# t_311_items save into rds successfully
# 2021-04-26 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210426.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210426.csv from s3 successfully
# (1293, 41)
# (1293, 16)
# t_311_items save into rds successfully
# 2021-04-27 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210427.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210427.csv from s3 successfully
# (1328, 41)
# (1328, 16)
# t_311_items save into rds successfully
# 2021-04-28 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210428.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210428.csv from s3 successfully
# (2218, 41)
# (2218, 16)
# t_311_items save into rds successfully
# 2021-04-29 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210429.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210429.csv from s3 successfully
# (1577, 41)
# (1577, 16)
# t_311_items save into rds successfully
# 2021-04-30 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210430.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210430.csv from s3 successfully
# (1420, 41)
# (1420, 16)
# t_311_items save into rds successfully
# 2021-05-01 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210501.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210501.csv from s3 successfully
# (3158, 41)
# (3158, 16)
# t_311_items save into rds successfully
# 2021-05-02 00:00:00
# s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210502.csv
#  load s3://information-arch-yuehao-wang-assignment-8a/Group_2_311_daily20210502.csv from s3 successfully
# (997, 39)
# (997, 16)
# t_311_items save into rds successfully
